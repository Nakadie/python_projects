# %% [markdown]
# # 1. Import dependencies

# %%
#import all the required parts for running the program
import os
import gym
import stable_baselines3
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
#create the environment name as well as the type of environment
environment_name = 'CartPole-v0'
env = gym.make(environment_name)

# %% [markdown]
# # 2. Load Env

# %%
# example env that runs for 5 episodes doing random actions 
episodes = 5
for episode in range(1, episodes + 1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:43.0
# Episode:2 Score:10.0
# Episode:3 Score:13.0
# Episode:4 Score:15.0
# Episode:5 Score:15.0

# %%
episodes = 5
for episode in range(1, episodes+1):
    print(episode)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # 3. Train an RL Model

# %%
#building directory
log_path =  os.path.join('Training', 'Logs')

# %%
# recreation of the environment same as the initialization
env = gym.make(environment_name) 
# wrapper for the environment, creates lambda function in the env, like a wrapper for non vectorized env
env = DummyVecEnv([lambda: env]) 
#defining the model which defines the agent, passing through 2 args and 2 kwargs
#mlppolicy = multilayer perceptron policy. using NN with standard NN units
# tensorboard log is where it saves
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
# here is number of training times and actual learning program. 
model.learn(total_timesteps = 20000)
# Out:
# Logging to Training\Logs\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 1736 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1124         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0032464939 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.491        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.8         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00513     |
# |    value_loss           | 101          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 998          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0018367018 |
# |    clip_fraction        | 0.00811      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41           |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 145          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 949        |
# |    iterations           | 4          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00864591 |
# |    clip_fraction        | 0.0816     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.559     |
# |    explained_variance   | 0.702      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33         |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00561   |
# |    value_loss           | 72.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004836344 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.3        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 156         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 6            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0023516952 |
# |    clip_fraction        | 0.00776      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | 0.259        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 73.8         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 147          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 888          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0056786737 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.551       |
# |    explained_variance   | 0.28         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 119          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 8            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0066025397 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.293        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96.5         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 172          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 868          |
# |    iterations           | 9            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0023123645 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.6         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 103          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 10           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0036971555 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.8         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 150          |
# ------------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
# this is the save location for the training above
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')

# %%
#actually saves the model
model.save(PPO_Path)

# %%
del model

# %%
# actually loads the model
model = PPO.load(PPO_Path, env=env)

# %% [markdown]
# # 5. Eval

# %%
#ep_len_mean == how long a episode lasts before done
#ep_rew_mean == average reward agent accumlated per episode

# %%
#this evaluates how well the agent performed over 10 episodes
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# (x, y) x == average reward, y == deviation
# Out:
# C:\Users\Kamuela\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12668/1328276589.py in <module>
#       1 #this evaluates how well the agent performed over 10 episodes
# ----> 2 evaluate_policy(model, env, n_eval_episodes=10, render=True)
#       3 # (x, y) x == average reward, y == deviation
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\evaluation.py in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#     121
#     122         if render:
# --> 123             env.render()
#     124
#     125     mean_reward = np.mean(episode_rewards)
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in render(self, mode)
#      83         """
#      84         if self.num_envs == 1:
# ---> 85             return self.envs[0].render(mode=mode)
#      86         else:
#      87             return super().render(mode=mode)
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\gym\envs\classic_control\cartpole.py in render(self, mode)
#     227         self.poletrans.set_rotation(-x[2])
#     228
# --> 229         return self.viewer.render(return_rgb_array=mode == "rgb_array")
#     230
#     231     def close(self):
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\gym\envs\classic_control\rendering.py in render(self, return_rgb_array)
#     143             arr = arr.reshape(buffer.height, buffer.width, 4)
#     144             arr = arr[::-1, :, 0:3]
# --> 145         self.window.flip()
#     146         self.onetime_geoms = []
#     147         return arr if return_rgb_array else self.isopen
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\pyglet\window\win32\__init__.py in flip(self)
#     378             self.update_transparency()
#     379
# --> 380         self.context.flip()
#     381
#     382     def set_location(self, x, y):
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\pyglet\gl\win32.py in flip(self)
#     250
#     251     def flip(self):
# --> 252         _gdi32.SwapBuffers(self.canvas.hdc)
#     253
#     254     def get_vsync(self):
#
# KeyboardInterrupt:

# %%
env.close()

# %% [markdown]
# # 6. Test
# taking observations and passing it to the agent to make its own choices.

# %%
action, _ = model.predict(obs)

# %%
# change action, 
episodes = 5
for episode in range(1, episodes + 1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(obs) # now using the model here
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:[200.]
# Episode:2 Score:[200.]
# Episode:3 Score:[200.]
# Episode:4 Score:[200.]
# Episode:5 Score:[200.]

# %%
env.reset()
# Out:
# array([ 0.03675869,  0.01465941,  0.01882426, -0.02708192], dtype=float32)

# %%
obs = env.reset()

# %%
#returns a action
action, _ = model.predict(obs)

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.step(action)
# reward is 1.0
# Out:
# C:\Users\Kamuela\anaconda3\envs\RLin3hr\lib\site-packages\gym\logger.py:34: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# (array([-0.19100748, -1.986649  ,  0.3022123 ,  3.2176414 ], dtype=float32),
#  0.0,
#  True,
#  {})

# %% [markdown]
# # 7. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_2')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_2'

# %%
# using ! is a magic command, can use command line command.
# 
# !tensorboard --logdir={training_log_path}

# %%
# to improve training either train longer or hyperparameter tuning.

# %% [markdown]
# # Adding a callback to the training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=100, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 557  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 656         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008876718 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0126     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.75        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 53.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011756576 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 39.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011350448 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 49.3        |
# -----------------------------------------
# C:\Users\Kamuela\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.015406858 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 58.5        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 100

# %% [markdown]
# # Changin Policies

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 1317 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014145174 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.000749    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.33        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 20.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018246926 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 26.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012616472 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.374       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 45.3        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.010057493 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.2         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 42.6        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 546   |
# |    iterations      | 5     |
# |    time_elapsed    | 18    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 6            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0035841726 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.708        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.5         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 33.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 7            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0047423784 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.538       |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.88         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 22           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 8           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007486368 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 33.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 526         |
# |    iterations           | 9           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005154619 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.72        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00184    |
# |    value_loss           | 39.9        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.009593809 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0087     |
# |    value_loss           | 24.1        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 514   |
# |    iterations      | 10    |
# |    time_elapsed    | 39    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# # 10. Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.966    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 934      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.925    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1181     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 158      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.873    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1371     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 267      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.829    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1386     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.748    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1612     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 531      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.716    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1533     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 598      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.683    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1527     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 667      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.649    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1573     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 739      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.59     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1692     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 863      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.563    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1692     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.539    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1683     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 970      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.49     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1743     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.457    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1749     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.394    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1837     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.353    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1867     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1363     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.307    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1907     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.277    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1897     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.234    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1921     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.204    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1927     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.143    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1981     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.105    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1992     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0514   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2030     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2025     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2027     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2044     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2047     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2064     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2077     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2062     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2077     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2137     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2166     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2151     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2195     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2199     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2192     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2198     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2192     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2192     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2196     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2231     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2250     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3958     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2262     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4065     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2262     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2275     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2280     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2286     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4404     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2288     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2287     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2285     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 4592     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2276     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 4645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2282     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 4728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2295     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 4832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2317     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 4974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2319     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2333     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2330     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2336     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5304     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2334     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2326     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5434     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2274     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              |