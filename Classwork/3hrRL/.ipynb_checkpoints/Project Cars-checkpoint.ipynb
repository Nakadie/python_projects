# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os
import pyglet

# %%
environment_name = 'CarRacing-v0'
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes + 1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Track generation: 1135..1429 -> 294-tiles track
# Episode:1 Score:-31.74061433447145
# Track generation: 1016..1274 -> 258-tiles track
# Episode:2 Score:-22.17898832684831
# Track generation: 1216..1525 -> 309-tiles track
# Episode:3 Score:-35.06493506493556
# Track generation: 1019..1278 -> 259-tiles track
# Episode:4 Score:-22.480620155038753
# Track generation: 1027..1291 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1160..1454 -> 294-tiles track
# Episode:5 Score:-28.32764505119486

# %% [markdown]
# # 3. Train Model

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps = 100000)
# Out:
# Track generation: 1081..1356 -> 275-tiles track
# Logging to Training\Logs\PPO_5
# Track generation: 1363..1707 -> 344-tiles track
# Track generation: 1301..1630 -> 329-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 89   |
# |    iterations      | 1    |
# |    time_elapsed    | 22   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1183..1483 -> 300-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 2           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008332714 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | -0.00836    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0965      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00958    |
# |    std                  | 0.986       |
# |    value_loss           | 0.579       |
# -----------------------------------------
# Track generation: 1097..1381 -> 284-tiles track
# Track generation: 968..1214 -> 246-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 3           |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010365215 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.099       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0789      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.973       |
# |    value_loss           | 0.396       |
# -----------------------------------------
# Track generation: 1192..1494 -> 302-tiles track
# Track generation: 1119..1415 -> 296-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 4           |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010854179 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.0106      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0433      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.966       |
# |    value_loss           | 0.408       |
# -----------------------------------------
# Track generation: 1150..1442 -> 292-tiles track
# Track generation: 1275..1598 -> 323-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 5           |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017343547 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0566      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.96        |
# |    value_loss           | 0.327       |
# -----------------------------------------
# Track generation: 1264..1584 -> 320-tiles track
# Track generation: 1084..1360 -> 276-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 6           |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015513988 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0437      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.955       |
# |    value_loss           | 0.366       |
# -----------------------------------------
# Track generation: 1141..1430 -> 289-tiles track
# Track generation: 903..1140 -> 237-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 7           |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.025397891 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.031      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0363     |
# |    std                  | 0.944       |
# |    value_loss           | 0.201       |
# -----------------------------------------
# Track generation: 1339..1678 -> 339-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 8           |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018752145 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00775    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0307     |
# |    std                  | 0.932       |
# |    value_loss           | 0.325       |
# -----------------------------------------
# Track generation: 1019..1285 -> 266-tiles track
# Track generation: 984..1235 -> 251-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1119..1403 -> 284-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 9           |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023013785 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00409    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.928       |
# |    value_loss           | 0.245       |
# -----------------------------------------
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 957..1208 -> 251-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 10          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018422974 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0266     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.916       |
# |    value_loss           | 0.199       |
# -----------------------------------------
# Track generation: 1067..1339 -> 272-tiles track
# Track generation: 1167..1462 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 11          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.023684554 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0498     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.909       |
# |    value_loss           | 0.18        |
# -----------------------------------------
# Track generation: 984..1244 -> 260-tiles track
# Track generation: 1149..1447 -> 298-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 12         |
# |    time_elapsed         | 495        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02412488 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.96      |
# |    explained_variance   | 0.81       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0138     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0297    |
# |    std                  | 0.902      |
# |    value_loss           | 0.219      |
# ----------------------------------------
# Track generation: 1120..1404 -> 284-tiles track
# Track generation: 1074..1353 -> 279-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 13          |
# |    time_elapsed         | 538         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.026609622 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00246    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.891       |
# |    value_loss           | 0.244       |
# -----------------------------------------
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1348..1689 -> 341-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 14          |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.031703778 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0497     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0382     |
# |    std                  | 0.881       |
# |    value_loss           | 0.185       |
# -----------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1035..1298 -> 263-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 15         |
# |    time_elapsed         | 626        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03544099 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.85      |
# |    explained_variance   | 0.808      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0551    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0372    |
# |    std                  | 0.869      |
# |    value_loss           | 0.183      |
# ----------------------------------------
# Track generation: 1110..1396 -> 286-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 16          |
# |    time_elapsed         | 671         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.055548895 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0555     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.045      |
# |    std                  | 0.861       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 1024..1293 -> 269-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 17         |
# |    time_elapsed         | 715        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.03667252 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.79      |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0112    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.033     |
# |    std                  | 0.853      |
# |    value_loss           | 0.475      |
# ----------------------------------------
# Track generation: 1198..1501 -> 303-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 18          |
# |    time_elapsed         | 759         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.041036196 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0381     |
# |    std                  | 0.835       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1236..1549 -> 313-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 48        |
# |    iterations           | 19        |
# |    time_elapsed         | 803       |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0421393 |
# |    clip_fraction        | 0.321     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.69     |
# |    explained_variance   | 0.942     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0208   |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -0.034    |
# |    std                  | 0.825     |
# |    value_loss           | 0.244     |
# ---------------------------------------
# Track generation: 1132..1420 -> 288-tiles track
# Track generation: 1106..1379 -> 273-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 20         |
# |    time_elapsed         | 847        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.05185501 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.66      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0419     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0324    |
# |    std                  | 0.816      |
# |    value_loss           | 0.267      |
# ----------------------------------------
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 933..1173 -> 240-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 21          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.047912713 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0281     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.033      |
# |    std                  | 0.809       |
# |    value_loss           | 0.247       |
# -----------------------------------------
# Track generation: 1202..1507 -> 305-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 22         |
# |    time_elapsed         | 935        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.03293985 |
# |    clip_fraction        | 0.317      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.6       |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.131      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0362    |
# |    std                  | 0.802      |
# |    value_loss           | 0.712      |
# ----------------------------------------
# Track generation: 1119..1409 -> 290-tiles track
# Track generation: 1189..1492 -> 303-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 48         |
# |    iterations           | 23         |
# |    time_elapsed         | 980        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.05120336 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.58      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0338    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0441    |
# |    std                  | 0.796      |
# |    value_loss           | 0.246      |
# ----------------------------------------
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1013..1276 -> 263-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 24          |
# |    time_elapsed         | 1027        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.048028655 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.033      |
# |    std                  | 0.793       |
# |    value_loss           | 0.446       |
# -----------------------------------------
# Track generation: 1315..1648 -> 333-tiles track
# Track generation: 1153..1445 -> 292-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 25          |
# |    time_elapsed         | 1073        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.033697527 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.21        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.788       |
# |    value_loss           | 2.13        |
# -----------------------------------------
# Track generation: 1153..1445 -> 292-tiles track
# Track generation: 1117..1400 -> 283-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 26          |
# |    time_elapsed         | 1117        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.050840557 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0449      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.788       |
# |    value_loss           | 0.599       |
# -----------------------------------------
# Track generation: 1051..1321 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1069..1341 -> 272-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 27          |
# |    time_elapsed         | 1162        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.044143543 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.608       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 0.786       |
# |    value_loss           | 3.79        |
# -----------------------------------------
# Track generation: 1069..1349 -> 280-tiles track
# Track generation: 1368..1714 -> 346-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 28         |
# |    time_elapsed         | 1207       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.04446465 |
# |    clip_fraction        | 0.335      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.52      |
# |    explained_variance   | 0.727      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.215      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0289    |
# |    std                  | 0.783      |
# |    value_loss           | 2.86       |
# ----------------------------------------
# Track generation: 1099..1378 -> 279-tiles track
# Track generation: 1091..1368 -> 277-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 29          |
# |    time_elapsed         | 1251        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.037862085 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.297       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.778       |
# |    value_loss           | 1.78        |
# -----------------------------------------
# Track generation: 1088..1364 -> 276-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 47        |
# |    iterations           | 30        |
# |    time_elapsed         | 1296      |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0719822 |
# |    clip_fraction        | 0.396     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.49     |
# |    explained_variance   | 0.939     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.159     |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.0279   |
# |    std                  | 0.774     |
# |    value_loss           | 1.15      |
# ---------------------------------------
# Track generation: 1244..1559 -> 315-tiles track
# Track generation: 1162..1457 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 31         |
# |    time_elapsed         | 1341       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.05870273 |
# |    clip_fraction        | 0.374      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.533      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0284    |
# |    std                  | 0.771      |
# |    value_loss           | 1.92       |
# ----------------------------------------
# Track generation: 1133..1429 -> 296-tiles track
# Track generation: 1276..1599 -> 323-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 32          |
# |    time_elapsed         | 1385        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.054142598 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.232       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0301     |
# |    std                  | 0.768       |
# |    value_loss           | 1.89        |
# -----------------------------------------
# Track generation: 1080..1354 -> 274-tiles track
# Track generation: 1186..1485 -> 299-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 33          |
# |    time_elapsed         | 1430        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.041872352 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.182       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.769       |
# |    value_loss           | 1.79        |
# -----------------------------------------
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1190..1499 -> 309-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 34          |
# |    time_elapsed         | 1473        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.037236005 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.16        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.765       |
# |    value_loss           | 2.19        |
# -----------------------------------------
# Track generation: 1100..1379 -> 279-tiles track
# Track generation: 1160..1464 -> 304-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 35          |
# |    time_elapsed         | 1518        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.054140992 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.28        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0257     |
# |    std                  | 0.757       |
# |    value_loss           | 1.96        |
# -----------------------------------------
# Track generation: 1052..1319 -> 267-tiles track
# Track generation: 1181..1480 -> 299-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 47        |
# |    iterations           | 36        |
# |    time_elapsed         | 1560      |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0528239 |
# |    clip_fraction        | 0.386     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.39     |
# |    explained_variance   | 0.744     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.03      |
# |    n_updates            | 350       |
# |    policy_gradient_loss | -0.0164   |
# |    std                  | 0.751     |
# |    value_loss           | 2.77      |
# ---------------------------------------
# Track generation: 1063..1333 -> 270-tiles track
# Track generation: 1110..1396 -> 286-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 37          |
# |    time_elapsed         | 1601        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.070544854 |
# |    clip_fraction        | 0.412       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.367       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 0.742       |
# |    value_loss           | 1.91        |
# -----------------------------------------
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1272..1594 -> 322-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 38          |
# |    time_elapsed         | 1641        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.059914168 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.33       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.385       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.74        |
# |    value_loss           | 2.21        |
# -----------------------------------------
# Track generation: 1371..1718 -> 347-tiles track
# Track generation: 1312..1652 -> 340-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 39          |
# |    time_elapsed         | 1686        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.041405857 |
# |    clip_fraction        | 0.372       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.642       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.736       |
# |    value_loss           | 3.63        |
# -----------------------------------------
# Track generation: 1057..1327 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1243..1566 -> 323-tiles track
# Track generation: 1415..1773 -> 358-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 40         |
# |    time_elapsed         | 1730       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.07650556 |
# |    clip_fraction        | 0.413      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.29      |
# |    explained_variance   | 0.844      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.367      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0279    |
# |    std                  | 0.73       |
# |    value_loss           | 1.78       |
# ----------------------------------------
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1138..1433 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 41          |
# |    time_elapsed         | 1772        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.062805906 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.431       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.727       |
# |    value_loss           | 2.75        |
# -----------------------------------------
# Track generation: 1153..1446 -> 293-tiles track
# Track generation: 1029..1297 -> 268-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 42         |
# |    time_elapsed         | 1817       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.06235215 |
# |    clip_fraction        | 0.41       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.839      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0496     |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0251    |
# |    std                  | 0.718      |
# |    value_loss           | 1.09       |
# ----------------------------------------
# Track generation: 1119..1412 -> 293-tiles track
# Track generation: 1215..1530 -> 315-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 43          |
# |    time_elapsed         | 1862        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.055603642 |
# |    clip_fraction        | 0.42        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.345       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.71        |
# |    value_loss           | 2.85        |
# -----------------------------------------
# Track generation: 1131..1419 -> 288-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1125..1419 -> 294-tiles track
# Track generation: 1219..1528 -> 309-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 44          |
# |    time_elapsed         | 1907        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.095555514 |
# |    clip_fraction        | 0.434       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.173       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0296     |
# |    std                  | 0.701       |
# |    value_loss           | 1.37        |
# -----------------------------------------
# Track generation: 1215..1523 -> 308-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 45          |
# |    time_elapsed         | 1951        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.055574864 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.697       |
# |    value_loss           | 1.65        |
# -----------------------------------------
# Track generation: 1051..1320 -> 269-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1289..1616 -> 327-tiles track
# Track generation: 988..1245 -> 257-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 47        |
# |    iterations           | 46        |
# |    time_elapsed         | 1996      |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 0.1016371 |
# |    clip_fraction        | 0.436     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.14     |
# |    explained_variance   | 0.897     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.197     |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -0.031    |
# |    std                  | 0.694     |
# |    value_loss           | 1.61      |
# ---------------------------------------
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1079..1355 -> 276-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1069..1348 -> 279-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 47         |
# |    time_elapsed         | 2041       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.06434521 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.13      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.139      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0241    |
# |    std                  | 0.693      |
# |    value_loss           | 1.31       |
# ----------------------------------------
# Track generation: 1045..1310 -> 265-tiles track
# Track generation: 1078..1352 -> 274-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 48         |
# |    time_elapsed         | 2085       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.08313496 |
# |    clip_fraction        | 0.416      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.258      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0244    |
# |    std                  | 0.689      |
# |    value_loss           | 1.57       |
# ----------------------------------------
# Track generation: 1210..1517 -> 307-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 49          |
# |    time_elapsed         | 2130        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.061954267 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.194       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.685       |
# |    value_loss           | 2.68        |
# -----------------------------------------

# %% [markdown]
# # 4. Save Model

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_Model')

# %%
model.save(ppo_path)

# %%
del model

# %%
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\Kamuela\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# Track generation: 1131..1425 -> 294-tiles track
# Track generation: 1251..1568 -> 317-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# Track generation: 1133..1420 -> 287-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# (258.8428165316582, 124.34149975940585)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1188..1493 -> 305-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1252..1569 -> 317-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1124..1408 -> 284-tiles track
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12168/3108987609.py in <module>
#       2 while True:
#       3     action, _states = model.predict(obs)
# ----> 4     obs, rewards, dones, info = env.step(action)
#       5     env.render()
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      49                 obs = self.envs[env_idx].reset()
#      50             self._save_obs(env_idx, obs)
# ---> 51         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#      52
#      53     def seed(self, seed: Optional[int] = None) -> List[Union[None, int]]:
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in _obs_from_buf(self)
#      95
#      96     def _obs_from_buf(self) -> VecEnvObs:
# ---> 97         return dict_to_obs(self.observation_space, copy_obs_dict(self.buf_obs))
#      98
#      99     def get_attr(self, attr_name: str, indices: VecEnvIndices = None) -> List[Any]:
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\vec_env\util.py in copy_obs_dict(obs)
#      20     """
#      21     assert isinstance(obs, OrderedDict), f"unexpected type for observations '{type(obs)}'"
# ---> 22     return OrderedDict([(k, np.copy(v)) for k, v in obs.items()])
#      23
#      24
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\stable_baselines3\common\vec_env\util.py in <listcomp>(.0)
#      20     """
#      21     assert isinstance(obs, OrderedDict), f"unexpected type for observations '{type(obs)}'"
# ---> 22     return OrderedDict([(k, np.copy(v)) for k, v in obs.items()])
#      23
#      24
#
# <__array_function__ internals> in copy(*args, **kwargs)
#
# ~\anaconda3\envs\RLin3hr\lib\site-packages\numpy\lib\function_base.py in copy(a, order, subok)
#     790
#     791     """
# --> 792     return array(a, order=order, subok=subok, copy=True)
#     793
#     794 # Basic operations
#
# KeyboardInterrupt:

# %%
env.close()
